# %%
import pandas

# %%
dataset = pandas.read_csv('50_startups.csv')

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
dataset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
y = dataset["Profit"]

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
x = dataset[['R&D Spend', 'Administration', 'Marketing Spend']]

# %%
state = dataset["State"]

# %%
mydummy = pandas.get_dummies(state , drop_first=True)

# %%
x[["Florida", "New York"]] = mydummy
# Out:
# /var/folders/50/v6xcgpn90ts0sx3bpt1brxl40000gn/T/ipykernel_4105/1955145564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[["Florida", "New York"]] = mydummy

# %%
x
# Out:
#     R&D Spend  Administration  Marketing Spend  Florida  New York
# 0   165349.20       136897.80        471784.10    False      True
# 1   162597.70       151377.59        443898.53    False     False
# 2   153441.51       101145.55        407934.54     True     False
# 3   144372.41       118671.85        383199.62    False      True
# 4   142107.34        91391.77        366168.42     True     False
# 5   131876.90        99814.71        362861.36    False      True
# 6   134615.46       147198.87        127716.82    False     False
# 7   130298.13       145530.06        323876.68     True     False
# 8   120542.52       148718.95        311613.29    False      True
# 9   123334.88       108679.17        304981.62    False     False
# 10  101913.08       110594.11        229160.95     True     False
# 11  100671.96        91790.61        249744.55    False     False
# 12   93863.75       127320.38        249839.44     True     False
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
mymodel = LinearRegression()

# %%
mymodel.fit(x,y)
# Out:
# LinearRegression()

# %%
mymodel.coef_
# Out:
# array([ 8.06023114e-01, -2.70043196e-02,  2.69798610e-02,  1.98788793e+02,
#        -4.18870191e+01])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train, y_test  = train_test_split(x,y, test_size=0.20, random_state=14)

# %%
x_train.shape
# Out:
# (40, 5)

# %%
newbrain = LinearRegression()

# %%
newbrain.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
newbrain.coef_
# Out:
# array([7.94319796e-01, 5.80084698e-03, 2.92593986e-02, 8.57276345e+02,
#        1.39451978e+02])

# %%
x_test
# Out:
#     R&D Spend  Administration  Marketing Spend  Florida  New York
# 47       0.00       135426.92             0.00    False     False
# 21   78389.47       153773.43        299737.29    False      True
# 14  119943.24       156547.42        256512.92     True     False
# 30   61994.48       115641.28         91131.24     True     False
# 37   44069.95        51283.14        197029.42    False     False
# 40   28754.33       118546.05        172795.67    False     False
# 19   86419.70       153514.11             0.00    False      True
# 1   162597.70       151377.59        443898.53    False     False
# 2   153441.51       101145.55        407934.54     True     False
# 6   134615.46       147198.87        127716.82    False     False

# %%
y_pred = newbrain.predict(x_test)

# %%
y_test
# Out:
# 47     42559.73
# 21    111313.02
# 14    132602.65
# 30     99937.59
# 37     89949.14
# 40     78239.91
# 19    122776.86
# 1     191792.06
# 2     191050.39
# 6     156122.51
# Name: Profit, dtype: float64

# %%
y_pred
# Out:
# array([ 47193.55997146, 118475.87789957, 150952.05679539,  99845.95082458,
#         87476.05080217,  74991.66754708, 116082.81144293, 189428.86327247,
#        181669.52354906, 157926.4893144 ])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 5620.115654252397

# %%
import pandas as pd

# %%
df = pd.read_csv('50_Startups.csv')

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
y=df["Profit"]

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
x = df[['R&D Spend', 'Administration', 'Marketing Spend']]

# %%
state = df["State"]

# %%
mydummy = pd.get_dummies(state , drop_first=True)

# %%
x
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
mymodel = LinearRegression()

# %%
mymodel.fit(x,y)
# Out:
# LinearRegression()

# %%
mymodel.coef_
# Out:
# array([ 0.80571505, -0.02681597,  0.02722806])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train, y_test  = train_test_split(x,y, test_size=0.20, random_state=14)

# %%
x_train.shape
# Out:
# (40, 3)

# %%
newbrain = LinearRegression()

# %%
newbrain.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
newbrain.coef_
# Out:
# array([0.79203409, 0.00711863, 0.03061901])

# %%
x_test
# Out:
#     R&D Spend  Administration  Marketing Spend
# 47       0.00       135426.92             0.00
# 21   78389.47       153773.43        299737.29
# 14  119943.24       156547.42        256512.92
# 30   61994.48       115641.28         91131.24
# 37   44069.95        51283.14        197029.42
# 40   28754.33       118546.05        172795.67
# 19   86419.70       153514.11             0.00
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 6   134615.46       147198.87        127716.82

# %%
y_pred = newbrain.predict(x_test)

# %%
y_test
# Out:
# 47     42559.73
# 21    111313.02
# 14    132602.65
# 30     99937.59
# 37     89949.14
# 40     78239.91
# 19    122776.86
# 1     191792.06
# 2     191050.39
# 6     156122.51
# Name: Profit, dtype: float64

# %%
y_pred
# Out:
# array([ 47415.5012945 , 118810.89538818, 150419.15730216,  99166.74461323,
#         87754.26150038,  75360.57478996, 115991.60574288, 189903.70373063,
#        181192.92388948, 158029.89754809])
