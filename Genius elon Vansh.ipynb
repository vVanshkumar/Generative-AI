# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in f:\anacondaa\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in f:\anacondaa\lib\site-packages (from opencv-python) (1.26.4)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

eye_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_eye.xml"
)

smile_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_smile.xml"
)

# %%
print("Face Cascade:", not face_cascade.empty())
print("Eye Cascade:", not eye_cascade.empty())
print("Smile Cascade:", not smile_cascade.empty())
# Out:
# Face Cascade: True
# Eye Cascade: True
# Smile Cascade: True

# %%
import cv2

# Start webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        print("Cannot access webcam")
        break

    # Convert frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.3,
        minNeighbors=5
    )

    for (x, y, w, h) in faces:

        # Draw face rectangle
        cv2.rectangle(
            frame,
            (x, y),
            (x + w, y + h),
            (255, 0, 0),
            2
        )

        cv2.putText(
            frame,
            "Face",
            (x, y - 10),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.8,
            (255, 0, 0),
            2
        )

        # Region of Interest for eyes and smile
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]

        # Detect eyes
        eyes = eye_cascade.detectMultiScale(
            roi_gray,
            scaleFactor=1.1,
            minNeighbors=5
        )

        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(
                roi_color,
                (ex, ey),
                (ex + ew, ey + eh),
                (0, 255, 0),
                2
            )

        # Detect smile
        smiles = smile_cascade.detectMultiScale(
            roi_gray,
            scaleFactor=1.7,
            minNeighbors=20
        )

        for (sx, sy, sw, sh) in smiles:
            cv2.rectangle(
                roi_color,
                (sx, sy),
                (sx + sw, sy + sh),
                (0, 0, 255),
                2
            )

    # Display webcam
    cv2.imshow("Face, Eye and Smile Detection", frame)

    # Press Q to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release webcam
cap.release()
cv2.destroyAllWindows()

# %%
a=45

# %%
a
# Out:
# 45

# %%
b=5.6666

# %%
b
# Out:
# 5.6666

# %%
c="Rudraksh Sharma"

# %%
c
# Out:
# 'Rudraksh Sharma'

# %%
d= "Vansh Kumar"

# %%
d
# Out:
# 'Vansh Kumar'

# %%
c+d
# Out:
# 'Rudraksh SharmaVansh Kumar'

# %%
c-d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 c-d
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
d-c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 d-c
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
c/d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 c/d
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
c+d
# Out:
# 'Rudraksh SharmaVansh Kumar'
