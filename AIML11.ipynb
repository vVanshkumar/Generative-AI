# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('50_Startups.csv')

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'R&D Spend'}>,
#         <Axes: title={'center': 'Administration'}>],
#        [<Axes: title={'center': 'Marketing Spend'}>,
#         <Axes: title={'center': 'Profit'}>]], dtype=object)

# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv('diabetes.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('house_market_value_data_with_states.csv')

# %%
dataframe
# Out:
#     Area  Bedrooms  Age  Distance_to_City  Crime_Rate  Market_Value      State
# 0   3674         1   49              5.97        5.65     128594.23     Punjab
# 1   1360         5   49             33.51        3.91      40207.11  Karnataka
# 2   1794         5   12              1.25        8.16     204876.63  Karnataka
# 3   1630         2   39              8.88        3.44      80724.84         UP
# 4   1595         5    2             27.89        4.95      27835.32         UP
# ..   ...       ...  ...               ...         ...           ...        ...
# 95  2817         2   38             27.04        9.12      45624.49      Delhi
# 96  1315         4   40             27.49        5.55      77493.20  Karnataka
# 97  3842         3   20             32.23        8.44     199976.15         UP
# 98   955         1   35             36.58        3.88      38887.99  Karnataka
# 99  1775         4   48             48.82        9.06     144155.08  Karnataka
#
# [100 rows x 7 columns]

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dataframe.size
# Out:
# 700

# %%
dataframe.shape
# Out:
# (100, 7)

# %%
dataframe
# Out:
#     Area  Bedrooms  Age  Distance_to_City  Crime_Rate  Market_Value      State
# 0   3674         1   49              5.97        5.65     128594.23     Punjab
# 1   1360         5   49             33.51        3.91      40207.11  Karnataka
# 2   1794         5   12              1.25        8.16     204876.63  Karnataka
# 3   1630         2   39              8.88        3.44      80724.84         UP
# 4   1595         5    2             27.89        4.95      27835.32         UP
# ..   ...       ...  ...               ...         ...           ...        ...
# 95  2817         2   38             27.04        9.12      45624.49      Delhi
# 96  1315         4   40             27.49        5.55      77493.20  Karnataka
# 97  3842         3   20             32.23        8.44     199976.15         UP
# 98   955         1   35             36.58        3.88      38887.99  Karnataka
# 99  1775         4   48             48.82        9.06     144155.08  Karnataka
#
# [100 rows x 7 columns]

# %%
import numpy as np

# %%
import pandas as pd

# %%
df1= pd.read_csv('employees.csv')

# %%
df1
# Out:
#    Name  Age      City  Salary   Bonus
# 0  John   28  New York   70000  7000.0
# 1  Sara   22     Paris   65000  6500.0
# 2  Mike   32    London   80000  8000.0
# 3  Emma   29     Tokyo   75000  7500.0

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Salary'}>],
#        [<Axes: title={'center': 'Bonus'}>, <Axes: >]], dtype=object)

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.isnull().sum()
# Out:
# Name      0
# Age       0
# City      0
# Salary    0
# Bonus     0
# dtype: int64

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
a=55
a
# Out:
# 55

# %%
type(a)
# Out:
# int

# %%
a
# Out:
# 55

# %%
a
# Out:
# 55

# %%
a
# Out:
# 55

# %%
a
# Out:
# 55

# %%
b=4.5
b
# Out:
# 4.5

# %%
b
# Out:
# 4.5

# %%
type(b)
# Out:
# float

# %%
b
# Out:
# 4.5

# %%
b
# Out:
# 4.5

# %%
c="string"
c
# Out:
# 'string'

# %%
type(c)
# Out:
# str

# %%
c
# Out:
# 'string'

# %%
c
# Out:
# 'string'

# %%
c.capitalize()
# Out:
# 'String'

# %%
c.upper()
# Out:
# 'STRING'

# %%
c.lower()
# Out:
# 'string'
